# %% [markdown]
# <a href="https://colab.research.google.com/github/suha-p/LGMVIP-october-Data-science-intern/blob/main/Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LGM VIP TASK 2 : Image to Pencil Sketch with Python ML Project
# #Beginner Level
# #Name : Suha P

# %% [markdown]
# #Import required libraries

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# #Importing Image

# %%
image = cv2.imread("/content/Sundar_pichai.png")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x873 at 0x7F9BC9F32290>

# %% [markdown]
# #Converting the original image to greyscale

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=640x873 at 0x7F9BC9EC5F90>

# %% [markdown]
# #Inverting the greyscale image

# %%
inverted_image = 255 - grey_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=640x873 at 0x7F9BC9ECB550>

# %% [markdown]
# #Blurring the image by using the Gaussian Function in OpenCV

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=640x873 at 0x7F9BC9EAED50>

# %% [markdown]
# #Pencil Sketch

# %%
def pencil_sketch(a, b):
  return cv2.divide(a, 255 - b, scale=256)
pencil_sketch=pencil_sketch(grey_image,blurred)
# Out:
# <PIL.Image.Image image mode=L size=640x873 at 0x7F9BC9EC5410>
